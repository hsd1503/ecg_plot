# %%
from ecg_plot import *

# %%
fs = 125
ecg = np.load('./ecg.npy').astype(float)# /1000

plot(ecg, sample_rate = fs, title = None, columns = 1, row_height = 3)
plt.show()
plt.close()

# %%
fs = 125
ecg = np.load('./ecg.npy').astype(float)# /1000
print(ecg.shape)

plot(ecg[:,:1000], sample_rate = fs, title = None, columns = 1, row_height = 3)
save_as_png('ecg')
# Out:
# (12, 3000)
